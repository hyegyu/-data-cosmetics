# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import time

# %%
import pandas as pd
df = pd.DataFrame(columns=['name', 'brand', 'price', 'ingredient'])

driver = webdriver.Chrome('/Users/yhg31/chromedriver.exe')
url = "https://www.oliveyoung.co.kr/store/goods/getGoodsDetail.do?goodsNo=A000000121562&dispCatNo=1000001000200060003&trackingCd=Cat100000100020006_MID"
driver.get(url)
#time.sleep(5)
        
#name=driver.find_element_by_xpath('''/html/body/div[2]/div[7]/div/div[2]/div[2]/div/p[2]''').text.strip()
#brand=driver.find_element_by_xpath('''/html/body/div[2]/div[7]/div/div[2]/div[2]/div/p[1]''').text.strip()
#price=driver.find_element_by_xpath('''/html/body/div[2]/div[7]/div/div[2]/div[2]/div/div[1]/span[1]/strike''').text.strip() 
ingredient=driver.find_element_by_xpath('''//*[@id="buyInfo"]''').click()
ingredient=driver.find_element_by_xpath('''/html/body/div[2]/div[7]/div/div[7]/div[2]/dl[7]/dd''').text

# %%
print(name, brand, price)
# Out:
# 페리페라 잉크더에어리벨벳 페리페라 9,000

# %%
ingredient
# Out:
# '01레드맛집 다이메티콘,사이클로펜타실록세인,다이메티콘크로스폴리머,사이클로헥사실록세인,폴리글리세릴-2트라이아이소스테아레이트,1,2-헥산디올,티타늄디옥사이드,탤크,황색5호,다이메티콘/비닐다이메티콘크로스폴리머,페닐트라이메티콘,부틸옥틸살리실레이트,에칠헥실살리실레이트,황색산화철,적색202호,적색산화철,사이클로테트라실록세인,페녹시에탄올,토코페릴아세테이트,적색104호의(1),C30-45알킬다이메티콘,향료,벤질벤조에이트, 리날룰, 아밀신남알, 헥실신남알,녹차씨오일,코튼씨오일,망고씨오일 02셀기꾼템 다이메티콘,사이클로펜타실록세인,다이메티콘크로스폴리머,사이클로헥사실록세인,폴리글리세릴-2트라이아이소스테아레이트,1,2-헥산디올,티타늄디옥사이드,황색5호,탤크,황색산화철,다이메티콘/비닐다이메티콘크로스폴리머,페닐트라이메티콘,부틸옥틸살리실레이트,에칠헥실살리실레이트,적색산화철,사이클로테트라실록세인,페녹시에탄올,적색104호의(1),토코페릴아세테이트,C30-45알킬다이메티콘,향료,벤질벤조에이트, 리날룰, 아밀신남알, 헥실신남알,적색202호,흑색산화철,녹차씨오일,코튼씨오일,망고씨오일 03만찢코랄 다이메티콘,사이클로펜타실록세인,다이메티콘크로스폴리머,사이클로헥사실록세인,폴리글리세릴-2트라이아이소스테아레이트,티타늄디옥사이드,1,2-헥산디올,탤크,적색산화철,다이메티콘/비닐다이메티콘크로스폴리머,페닐트라이메티콘,부틸옥틸살리실레이트,에칠헥실살리실레이트,사이클로테트라실록세인,페녹시에탄올,적색104호의(1),황색5호,토코페릴아세테이트,황색산화철,C30-45알킬다이메티콘,향료,벤질벤조에이트, 리날룰, 아밀신남알, 헥실신남알,녹차씨오일,코튼씨오일,망고씨오일 04인간벚꽃 다이메티콘,사이클로펜타실록세인,다이메티콘크로스폴리머,사이클로헥사실록세인,폴리글리세릴-2트라이아이소스테아레이트,티타늄디옥사이드,1,2-헥산디올,적색산화철,탤크,다이메티콘/비닐다이메티콘크로스폴리머,페닐트라이메티콘,부틸옥틸살리실레이트,에칠헥실살리실레이트,적색104호의(1),사이클로테트라실록세인,페녹시에탄올,황색4호,토코페릴아세테이트,C30-45알킬다
# ...
